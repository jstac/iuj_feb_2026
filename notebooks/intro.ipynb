# %% [markdown]
# $$
# \newcommand{\argmax}{arg\,max}
# \newcommand{\argmin}{arg\,min}
# $$

# %% [markdown]
# # Computational Methods for Simulation

# %% [markdown]
# ## An Analysis of the Schelling Model
#
# **Prepared for the International University of Japan**
#
# **Author: [John Stachurski](https://johnstachurski.net/)**
#
# This workshop explores simulation for economic analysis.
#
# It demonstrates how to accelerate simulations using modern Python tools.
#
# This workshop focuses on Thomas Schelling’s segregation model as our running example.
#
# The key ideas can be applied in other settings.

# %% [markdown]
# ## Overview
#
# The Schelling segregation model shows how mild individual preferences can lead to extreme aggregate outcomes. We study:
#
# 1. **The basic model** — Understanding the dynamics of racial segregation using Python classes
# 1. **NumPy implementation** — Rewriting the model with arrays and functions for clarity and speed
# 1. **JAX implementation** — Translating the model to JAX syntax and concepts
# 1. **Further parallelization** — How can we exploit modern parallel hardware (e.g., GPUs)

# %% [markdown]
# ## Schelling Model
#
# - [Racial Segregation](https://quantecon.github.io/iuj_feb_2026/segregation_background.html)
# - [The Schelling Model](https://quantecon.github.io/iuj_feb_2026/schelling.html)
# - [Schelling Model with NumPy](https://quantecon.github.io/iuj_feb_2026/schelling_numpy.html)
# - [Schelling Model with JAX](https://quantecon.github.io/iuj_feb_2026/schelling_jax.html)
# - [Schelling Model: Performance Comparison](https://quantecon.github.io/iuj_feb_2026/schelling_jax_parallel.html)
# - [Segregation with Persistent Shocks](https://quantecon.github.io/iuj_feb_2026/schelling_shocks.html)
